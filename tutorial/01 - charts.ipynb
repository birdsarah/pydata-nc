# %% [markdown]
# <table style="float:left; border:none">
#    <tr style="border:none">
#        <td style="border:none">
#            <a href="http://bokeh.pydata.org/">
#            <img
#                src="assets/images/bokeh-transparent.png"
#                style="width:50px"
#            >
#            </a>
#        </td>
#        <td style="border:none">
#            <h1>Bokeh Tutorial</h1>
#        </td>
#    </tr>
# </table>
#
# <div style="float:right;"><h2>01. High Level Charts</h2></div>

# %% [markdown]
# This section covers the `bokeh.charts` interface, which is a high-level API that is especially useful for exploratory data analysis (for instance, in a Jupyter notebook). It provides functions for quickly producing many standard chart types, often with a single line of code. We will look at the following types in this notebook:
#
# * [Scatter Plot](#Scatter-Plot)
# * [Bar Chart](#Bar-Chart)
# * [Histogram](#Histogram)
# * [Box Plot](#Box-Plot)

# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="23ff84e1-c5ec-4cec-9847-b5f2e170768c">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Scatter Plot
#
# A high-level scatter plot is provided by [`bokeh.charts.Scatter`]().
#
# For this section will use the "iris" data set. First let's import it and take a look at a few rows:

# %%
from bokeh.sampledata.iris import flowers
flowers.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from bokeh.charts import Scatter

# %% [markdown]
# A basic scatter chart takes the data (in this case a pandas DataFrame) as the first argument, and specifies the `x` and `y` coordinates for the scatter as the names of columns in the data.

# %%
p = Scatter(flowers, x='petal_length', y='petal_width')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c3f133cd-fc2f-4ed2-9f45-94806b4cd12e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c3f133cd-fc2f-4ed2-9f45-94806b4cd12e").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c3f133cd-fc2f-4ed2-9f45-94806b4cd12e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c3f133cd-fc2f-4ed2-9f45-94806b4cd12e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"4cb378ec-b5c0-4951-82b2-d83a15e0058c":{"roots":{"references":[{"attributes":{"overlay":{"id":"8a312bbe-cffe-46d4-8e02-8779e339c3c4","type":"BoxAnnotation"},"plot":{"id":"92c7fa4a-fa38-46d2-854e-ca0097fed8c9","subtype":"Chart","type":"Plot"}},"id":"dbf237e3-c38f-4dfd-b8a2-ec2c92b02bfc","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"92c7fa4a-fa38-46d2-854e-ca0097fed8c9","subtype":"Chart","type":"Plot"}},"id":"8e3a5101-1336-4119-b825-bbc0629654c3","type":"HelpTool"},{"attributes":{"plot":{"id":"92c7fa4a-fa38-46d2-854e-ca0097fed8c9","subtype":"Chart","type":"Plot"}},"id":"0a8fc625-f77d-4dc3-8947-6c463cc0eeca","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"92c7fa4a-fa38-46d2-854e-ca0097fed8c9","subtype":"Chart","type":"Plot"},"ticker":{"id":"c7398a65-d813-489d-acd8-54294600d4e3","type":"BasicTicker"}},"id":"3d464e5c-833c-49d8-a3a3-56cb2bc7a762","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"92c7fa4a-fa38-46d2-854e-ca0097fed8c9","subtype":"Chart","type":"Plot"},"ticker":{"id":"53adc1e2-324e-4a71-a533-8fc105af07e4","type":"BasicTicker"}},"id":"da417415-79ad-4ab3-be8a-1b0ddad0bf86","type":"Grid"},{"attributes":{},"id":"e7c60b4b-050b-4906-ba78-9133753ca1af","type":"BasicTickFormatter"},{"attributes":{"axis_label":"petal_length","formatter":{"id":"35d0e3b5-e081-4dc3-8385-7eff0dfdfbe4","type":"BasicTickFormatter"},"plot":{"id":"92c7fa4a-fa38-46d2-854e-ca0097fed8c9","subtype":"Chart","type":"Plot"},"ticker":{"id":"c7398a65-d813-489d-acd8-54294600d4e3","type":"BasicTicker"}},"id":"7039ba7b-f2aa-418f-8d37-6a180e379071","type":"LinearAxis"},{"attributes":{"plot":{"id":"92c7fa4a-fa38-46d2-854e-ca0097fed8c9","subtype":"Chart","type":"Plot"}},"id":"ceddfe7c-e260-47e5-ba79-d077d5c04d23","type":"SaveTool"},{"attributes":{"callback":null,"end":7.49,"start":0.4099999999999999},"id":"e0331535-16eb-4d39-968c-de1f668a8a02","type":"Range1d"},{"attributes":{"data_source":{"id":"626c2a1d-1abf-4078-9740-a3c4915a975e","type":"ColumnDataSource"},"glyph":{"id":"53f4a5dd-15d7-4bf0-8dfd-17bc42a8a6be","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"96bf679e-b443-4e5b-b367-3abf17ec5afc","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":null},"id":"cd7a245c-b0f4-43df-9b74-0e357c7f299b","type":"Title"},{"attributes":{"callback":null,"end":2.74,"start":-0.13999999999999999},"id":"a7d1b91e-64f6-41fd-82ac-d6cf4417b5ad","type":"Range1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8a312bbe-cffe-46d4-8e02-8779e339c3c4","type":"BoxAnnotation"},{"attributes":{},"id":"35d0e3b5-e081-4dc3-8385-7eff0dfdfbe4","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"92c7fa4a-fa38-46d2-854e-ca0097fed8c9","subtype":"Chart","type":"Plot"}},"id":"1b375e1f-6a65-4ef8-a88d-be9ab15669f2","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":[1.4,1.4,1.3,1.5,1.4,1.7,1.4,1.5,1.4,1.5,1.5,1.6,1.4,1.1,1.2,1 ...

# %% [markdown]
# By passing a column name for the `color` parameter, you can make `Scatter` automatically color the markers according to the groups in that column. Let's also add a legend by specify its location as the value of a `legend` paramter (in this case `"top_left"`)

# %%
p = Scatter(flowers, x='petal_length', y='petal_width', color='species', legend='top_left')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c9ce3574-559b-4a32-b143-8e963e01f890"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c9ce3574-559b-4a32-b143-8e963e01f890").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c9ce3574-559b-4a32-b143-8e963e01f890");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c9ce3574-559b-4a32-b143-8e963e01f890' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f75cd532-3c25-4012-bcf5-7aeb0efc5db3":{"roots":{"references":[{"attributes":{"plot":{"id":"8707bf0b-230e-455b-ab3e-037da476e245","subtype":"Chart","type":"Plot"}},"id":"c0c87e30-4358-4d96-ad31-8715a5fa6b5f","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2409e024-dc8e-48ce-b105-717689ecfb47","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c0c87e30-4358-4d96-ad31-8715a5fa6b5f","type":"PanTool"},{"id":"74c28b8b-11dd-4c88-8ea5-b03274156024","type":"WheelZoomTool"},{"id":"6240e347-1a00-4669-b7eb-702e8476d410","type":"BoxZoomTool"},{"id":"41693aae-6af5-4724-a55f-4c148dc95aa7","type":"SaveTool"},{"id":"51cc95a6-e40b-403a-93c3-a5542a739163","type":"ResetTool"},{"id":"00e22085-d8b3-4991-b3f4-644829fd1839","type":"HelpTool"}]},"id":"f8bb4f84-664c-4f43-aa01-1a206af3ea69","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"8707bf0b-230e-455b-ab3e-037da476e245","subtype":"Chart","type":"Plot"},"ticker":{"id":"f0494f54-e475-4366-89eb-883100c40bee","type":"BasicTicker"}},"id":"64f611fa-2f7a-479c-b29f-380b747e8a64","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#407ee7"},"line_color":{"value":"#407ee7"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"22326ad8-0bf9-4e85-9f94-d3ee791f0ee5","type":"Circle"},{"attributes":{"callback":null,"end":2.74,"start":-0.13999999999999999},"id":"c7790046-56ef-4710-ae00-1d4aa5761421","type":"Range1d"},{"attributes":{"callback":null,"end":7.49,"start":0.4099999999999999},"id":"3edf2d57-a3f3-46fd-9147-f0b5014f5fae","type":"Range1d"},{"attributes":{"data_source":{"id":"695468d4-ba05-401e-ab28-55ffe58ae1ca","type":"ColumnDataSource"},"glyph":{"id":"56624a9a-b4c9-46df-8889-12193a4848b6","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c4167d18-46e4-4df9-aa3e-cd7d9d0db379","type":"GlyphRenderer"},{"attributes":{},"id":"397daa4d-4560-40be-b27b-f096a2fb3b15","type":"ToolEvents"},{"attributes":{"axis_label":"petal_length","formatter":{"id":"ffad4787-7e92-43eb-903b-fcc8afbc08c1","type":"BasicTickFormatter"},"plot":{"id":"8707bf0b-230e-455b-ab3e-037da476e245","subtype":"Chart","type":"Plot"},"ticker":{"id":"4b2a3f99-604d-42e2-b3f8-a32bbc5239aa","type":"BasicTicker"}},"id":"edde2598-18fb-4255-8e2b-5de6ff75f39b","type":"LinearAxis"},{"attributes":{"plot":{"id":"8707bf0b-230e-455b-ab3e-037da476e245","subtype":"Chart","type":"Plot"}},"id":"00e22085-d8b3-4991-b3f4-644829fd1839","type":"HelpTool"},{"attributes":{"overlay":{"id":"2409e024-dc8e-48ce-b105-717689ecfb47","type":"BoxAnnotation"},"plot":{"id":"8707bf0b-230e-455b-ab3e-037da476e245","subtype":"Chart","type":"Plot"}},"id":"6240e347-1a00-4669-b7eb-702e8476d410","type":"BoxZoomTool"},{"attributes":{"legends":[["setosa",[{"id":"c4167d18-46e4-4df9-aa3e-cd7d9d0db379","type":"GlyphRenderer"}]],["versicolor",[{"id":"b2af9791-6bde-4c90-8f23-17c056f66539","type":"GlyphRenderer"}]],["virginica",[{"id":"cc6d5284-7af4-404e-9ae4-fedfe30d4635","type":"GlyphRenderer"}]]],"location":"top_left","plot":{"id":"8707bf0b-230e-455b-ab3e-037da476e245","subtype":"Chart","type":"Plot"}},"id":"83a5b83e-f413-44c5-9ca9-29e67e6f5257","type":"Legend"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"chart_index":[{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"specie ...

# %% [markdown]
# By passing a column name for the `marker` parameter, you can make `Scatter` automatically vary the marker shapes according to the groups in that column. Let's try that as an exercise.

# %%
# EXERCISE: vary the marker shape by passing a column name as the `marker` keyword argument

# %% [markdown]
# # Bar Chart
#
# A high-level bar chart is provided by [`bokeh.charts.Bar`]()
#
# For this section, we will use the "autompg" data set. Let's import it and take a quick look:

# %%
from bokeh.sampledata.autompg import autompg
autompg.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin                       name
# 0  18.0    8  307.0  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1  15.0    8  350.0  165    3693   11.5  70       1          buick skylark 320
# 2  18.0    8  318.0  150    3436   11.0  70       1         plymouth satellite
# 3  16.0    8  304.0  150    3433   12.0  70       1              amc rebel sst
# 4  17.0    8  302.0  140    3449   10.5  70       1                ford torino

# %%
from bokeh.charts import Bar

# %% [markdown]
# A basic bar chart takes the data (again a DataFrame) as the first value, as well as column names for:
#
# * `label` - a column to group to label the x-axis
# * `values` - a column to aggregate values for each group, to give the bar heights
# * `agg` - the name of an aggregation to perform over the values (e.g., `"mean"`, `"max"`, etc.)
#
# A simple example that also specifies some other properties such as `title` and `legend` is shown below:

# %%
p = Bar(autompg, label='cyl', values='mpg', agg='max', 
        title="Max MPG by CYL", legend=None, tools='crosshair')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="3feeb116-a1bc-449d-b05d-94758b0afd2e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#3feeb116-a1bc-449d-b05d-94758b0afd2e").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3feeb116-a1bc-449d-b05d-94758b0afd2e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3feeb116-a1bc-449d-b05d-94758b0afd2e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"85694654-4f49-4b1b-8b26-9588ea533dfc":{"roots":{"references":[{"attributes":{},"id":"ea76a056-6b65-444f-99d3-6895d6c5f39a","type":"BasicTickFormatter"},{"attributes":{"callback":null,"factors":["3","4","5","6","8"]},"id":"b666ea10-8558-4c01-bb04-b4a50459bce8","type":"FactorRange"},{"attributes":{"callback":null,"column_names":["line_alpha","label","x","line_color","height","fill_alpha","color","y","width"],"data":{"chart_index":[{"cyl":4}],"color":["#f22c40"],"cyl":[4],"fill_alpha":[0.8],"height":[46.6],"label":[{"cyl":4}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["4"],"y":[23.3]}},"id":"e2679e4a-ed72-4082-b8a8-4dfe9f28a2fe","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_alpha","label","x","line_color","height","fill_alpha","color","y","width"],"data":{"chart_index":[{"cyl":8}],"color":["#f22c40"],"cyl":[8],"fill_alpha":[0.8],"height":[26.6],"label":[{"cyl":8}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["8"],"y":[13.3]}},"id":"75419b4c-a223-42c6-9674-8f044c5f300a","type":"ColumnDataSource"},{"attributes":{},"id":"8a7f82be-2102-46fb-bf9a-350a5eec9033","type":"BasicTicker"},{"attributes":{"axis_label":"Cyl","formatter":{"id":"afc8315f-7713-44e4-9986-3fa1bac0939e","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"e7b81bcb-77b3-4f54-8cdf-6a2904cd0a85","subtype":"Chart","type":"Plot"},"ticker":{"id":"ed4551d4-ddf2-4f3c-ab22-df400524724e","type":"CategoricalTicker"}},"id":"aa07db7e-aab3-459e-b6c0-4610d8446cd1","type":"CategoricalAxis"},{"attributes":{"axis_label":"Max( Mpg )","formatter":{"id":"ea76a056-6b65-444f-99d3-6895d6c5f39a","type":"BasicTickFormatter"},"plot":{"id":"e7b81bcb-77b3-4f54-8cdf-6a2904cd0a85","subtype":"Chart","type":"Plot"},"ticker":{"id":"8a7f82be-2102-46fb-bf9a-350a5eec9033","type":"BasicTicker"}},"id":"8a6d8391-fd3b-4430-8ebe-7dd0d7cd2895","type":"LinearAxis"},{"attributes":{},"id":"8324b606-04f4-42b6-9fa7-b0a3a9b791bd","type":"ToolEvents"},{"attributes":{"data_source":{"id":"f57981a5-ec8d-4d44-a02e-795ab280e6d7","type":"ColumnDataSource"},"glyph":{"id":"59be222d-5d58-488c-9b01-ab1d82f49333","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d1b2498e-ef7f-4d57-bd83-2ccfed0a5bfb","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"ed2c42bf-2293-48fc-bbcc-e3a0bed3f359","type":"ColumnDataSource"},"glyph":{"id":"401604c4-2a8a-4bfe-bf6d-cbcc7f7b6c1d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"59c4bbc2-f5e8-4db3-a1ea-2b45838da406","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"75419b4c-a223-42c6-9674-8f044c5f300a","type":"ColumnDataSource"},"glyph":{"id":"b09d8598-22d9-4f56-ae6d-16a03586d367","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b69fb186-43bd-4b03-a4b8-583484567d99","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":"Max MPG by CYL"},"id":"ddff71ea-4a41-4862-807f-a59226de4b09","type":"Title"},{"attributes":{"data_source":{"id":"e2679e4a-ed72-4082-b8a8-4dfe9f28a2fe","type":"ColumnDataSource"},"glyph":{"id":"ae145647-807f-486a-bf93-cf9653155c01","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"996d6519-d3a1-4408-aef7-5ad0f8c81101","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"67fc3950-bf81-47d9-b90a-f5f7c8876af1","type":"CrosshairTool"}]},"id":"933bbd06-e283-4a96-94e4-588eb55a5bbb","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"e7b81bcb-77b3-4f54-8cdf-6a2904cd0a85","subtype":"Chart","type":"Plot"},"ticker":{"id":"8a7f82be-2102-46fb-bf9a-350a5eec9033","type":"BasicTicker"}},"id":"adee36a6-c324-4e32-ace3-0c780b72708c","type":"Grid"},{"attributes":{"plot":{"id":"e7b81bcb-77b3-4f54-8cdf-6a2904cd0a85","subtype":"Chart","type":"Plot"}},"id":"67fc3950-bf81-47d9-b90a-f5f7c8876af1","type":"Crossh ...

# %% [markdown]
# By passing another column name as the `group` parameter, the aggregations can be further subdivided by the groups in that column, and the bars grouped visually. The example below demonstrates this, as well as adding a legend by specifying its location:

# %%
p = Bar(autompg, label='yr', values='mpg', agg='median', group='origin', 
        title="Median MPG by YR, grouped by ORIGIN", legend='top_left', tools='crosshair')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f3acc122-e242-427a-8156-fe92bb711199"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#f3acc122-e242-427a-8156-fe92bb711199").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f3acc122-e242-427a-8156-fe92bb711199");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f3acc122-e242-427a-8156-fe92bb711199' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"599b8dc8-d021-488e-924c-59a8222fbb72":{"roots":{"references":[{"attributes":{"data_source":{"id":"25609fe7-04dc-4c9f-a1a3-35160f1eea28","type":"ColumnDataSource"},"glyph":{"id":"7df7c3e4-4d59-4a70-a73a-d768aa51fbc9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"622a3b89-f4de-4ac4-bc72-4f80740e0020","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e56be77e-c267-4bba-8745-c43c17e330f6","type":"Rect"},{"attributes":{"data_source":{"id":"acb6b230-3bb9-4c7a-8923-96b7a4574326","type":"ColumnDataSource"},"glyph":{"id":"542560af-2b0b-4f77-8669-1f21450ae7bc","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b287acd8-5ece-4262-9797-f13a371e30d4","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_alpha","label","x","line_color","height","fill_alpha","color","y","width"],"data":{"chart_index":[{"origin":3,"yr":71}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[29.0],"label":[{"origin":3,"yr":71}],"line_alpha":[1.0],"line_color":["white"],"origin":[3],"width":[0.2],"x":["71:0.5"],"y":[14.5],"yr":[71]}},"id":"f345ccbc-af5c-4a23-99d9-059c5f71937a","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_alpha","label","x","line_color","height","fill_alpha","color","y","width"],"data":{"chart_index":[{"origin":3,"yr":70}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[25.5],"label":[{"origin":3,"yr":70}],"line_alpha":[1.0],"line_color":["white"],"origin":[3],"width":[0.2],"x":["70:0.5"],"y":[12.75],"yr":[70]}},"id":"58526481-ff5d-4da8-bf8b-a331ce21dc37","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"71905b37-76e2-4955-81ab-88e61aac7177","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_alpha","label","x","line_color","height","fill_alpha","color","y","width"],"data":{"chart_index":[{"origin":1,"yr":73}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[14.0],"label":[{"origin":1,"yr":73}],"line_alpha":[1.0],"line_color":["white"],"origin":[1],"width":[0.2],"x":["73:0.25"],"y":[7.0],"yr":[73]}},"id":"7defa4ec-f980-4f6f-83ee-fc4f856987d6","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_alpha","label","x","line_color","height","fill_alpha","color","y","width"],"data":{"chart_index":[{"origin":1,"yr":76}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[18.25],"label":[{"origin":1,"yr":76}],"line_alpha":[1.0],"line_color":["white"],"origin":[1],"width":[0.2],"x":["76:0.25"],"y":[9.125],"yr":[76]}},"id":"0f8004b8-2189-4486-a429-8e8dfe5a4721","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"eb704c43-44ac-4904-9617-86a7fa274330","type":"ColumnDataSource"},"glyph":{"id":"029b1c0d-0af7-4ede-9b67-1ab912f66fd9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8371ed46-1097-4035-9b21-adae39ebc6c8","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"05b777ac-c71d-4226-b384-e1c027485b58","type":"Rect"},{"attributes":{"data_source":{"id":"67373c06-9eb8-4491-903e-97f789ad5191","type":"ColumnDataSource"},"glyph":{"id":"3b9c56db-7c86-41ff-adc9-8445fc261e74","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"256da16c-7221-40d5-8fef-93ba67966932","type":"GlyphRenderer"},{"attributes":{"callback":null,"column ...

# %% [markdown]
# Similarly, bars for subgroups can be stacked visually, by providing a column name for the `stack` parameter. Let's try that as an exercise.

# %%
# EXERCISE: change the chart above to stack the bars with title "Median MPG by YR, stacked by ORIGIN"

# %% [markdown]
# # Histogram
#
# A high-level Histogram is provided by [`bokeh.charts.Histogram`]()
#
# For this section, we will construct our own synthetic data set that has values generated from two different probability distributions.

# %%
import pandas as pd
import numpy as np

# build some distributions
mu, sigma = 0, 0.5
normal = pd.DataFrame({'value': np.random.normal(mu, sigma, 1000), 'type': 'normal'})
lognormal = pd.DataFrame({'value': np.random.lognormal(mu, sigma, 1000), 'type': 'lognormal'})

# create a pandas data frame
df = pd.concat([normal, lognormal])
df[995:1005]
# Out:
#           type     value
# 995     normal  0.901390
# 996     normal  0.333198
# 997     normal  0.076075
# 998     normal  0.245257
# 999     normal -0.264662
# 0    lognormal  1.220366
# 1    lognormal  0.592501
# 2    lognormal  1.698697
# 3    lognormal  1.088923
# 4    lognormal  0.721285

# %%
from bokeh.charts import Histogram

# %% [markdown]
# A basic histogram takes the data as the first parameter, and a column name as the `values` parameter. Optionally, you can also specify the number of bins to use by giving a value for the `bins` parameter. The example below shows the distribution of ***all*** the values (both the "normal" and "lognormal" values).

# %%
hist = Histogram(df, values='value', bins=30)
show(hist)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="2c81f431-9028-4dcb-9676-538aeafa1180"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#2c81f431-9028-4dcb-9676-538aeafa1180").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2c81f431-9028-4dcb-9676-538aeafa1180");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2c81f431-9028-4dcb-9676-538aeafa1180' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c218fb5e-3a0c-42a1-8285-f4976b34cc08":{"roots":{"references":[{"attributes":{"data_source":{"id":"8467b831-8fdc-4329-b268-a9cd1d2a4c0a","type":"ColumnDataSource"},"glyph":{"id":"05823c9e-4c07-4ed6-ad78-6f03b1d98b36","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7387fdbe-4952-41ea-8c24-eeab2da8ca32","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_alpha","label","x","line_color","height","fill_alpha","color","y","width"],"data":{"chart_index":["(2.6, 2.8]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[11.0],"label":["(2.6, 2.8]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.19638499422751376],"x":["2.7"],"y":[5.5]}},"id":"6ec0fc34-f690-4339-afef-542257d1f12e","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cce251b3-f01f-458c-96d5-3e333df48650","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"153ab803-7e74-412b-b76d-b9a2074f63c4","type":"Rect"},{"attributes":{"data_source":{"id":"8be888fb-cd50-4a65-b427-851bd5485a57","type":"ColumnDataSource"},"glyph":{"id":"cdb22f27-c543-4e1f-8414-19818a77a52a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7cbc0b0c-251c-4375-87fd-b31c87a67497","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"0bf12874-fccd-42f3-87ff-1d5fdff93821","type":"ColumnDataSource"},"glyph":{"id":"ede28af2-d1cd-4fb9-8fbd-f73c2bfae77d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2b978a16-999c-4f92-afe7-a578789d5a8e","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1978e3d1-e0b3-4155-9548-22cbfa013546","type":"Rect"},{"attributes":{"data_source":{"id":"3990c779-39e4-488e-acab-36a7fc0a5982","type":"ColumnDataSource"},"glyph":{"id":"18715e01-d981-4b72-99b7-c68c1283b31c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"fb7f4d91-e640-4056-8568-8cc7ab0a0356","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"91293c4d-e30c-4f66-b44d-c86a78aa0d3d","type":"ColumnDataSource"},"glyph":{"id":"b874c180-de00-4036-ab11-ae2cfaf3813f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"40c09a45-cc48-4be5-870c-fd6a7d600cce","type":"GlyphRenderer"},{"attributes":{},"id":"6a5bbb4d-dc68-4765-8edc-92f256bb505b","type":"BasicTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d54a4500-6ab4-4f44-9a0f-d2f1b90971cb","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ede28af2-d1cd-4fb9-8fbd-f73c2bfae77d","type":"Rect"},{"attributes":{"location":"top_left","plot":{"id":"0fc5ae36-82e3-4935-a5f9-80d7b67d943b","subtype":"Chart","type":"Plot"}},"id":"ae6e4367-78f7-4e67-92f8-f0df97b971d3","type":"Legend"},{"attributes":{"axis_label":"Count( Value )","formatter":{"id":"70cb3c30-6ff4-4022-89bf-55f010496e63","type":"BasicTickFormatter"},"plot":{"id":"0fc5ae36-82e3-4935-a5f9-80d7b67d943b","subtype":"Chart","type":"Pl ...

# %% [markdown]
# It's also possible to generate multiple histograms at once by grouping the data. The column to group by is specified by the `color` parameter (and the histogram for each group is colored differently automatically). Let's try that as an exercise.

# %%
# EXERCISE: generate histograms for each "type" of distribution, and add a legend to the top left.

# %% [markdown]
# # Box Plot
#
# A high-level box plot is provided by [`bokeh.charts.BoxPlot`]()
#
# For this section we will use the "iris" data set again.

# %%
from bokeh.charts import BoxPlot

# %% [markdown]
# A basic box plot takes the data as the first value, as well as column names for:
#
# * `label` - a column to group to label the x-axis
# * `values` - a column to aggregate values for each group
#
# A simple example that also specifies some other properties such as `title` and `legend` is shown below:

# %%
p = BoxPlot(flowers, label='species', values='petal_width', tools='crosshair', color='#aa4444',
            xlabel='', ylabel='petal width, mm', title='Distributions of petal widths')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="77d1547c-275c-4c22-b22a-b948fd2af4d6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#77d1547c-275c-4c22-b22a-b948fd2af4d6").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("77d1547c-275c-4c22-b22a-b948fd2af4d6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '77d1547c-275c-4c22-b22a-b948fd2af4d6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"db99f425-7a18-4827-b1ee-c70dba264646":{"roots":{"references":[{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"27dbd29e-83a5-4dfd-a47d-6ac7a0370bf4","type":"Segment"},{"attributes":{"legends":[["setosa",[{"id":"4be8238e-38ef-4a62-9ef7-222b9cdafeef","type":"GlyphRenderer"},{"id":"2bacc456-225b-4950-bc36-f47e3c4fcece","type":"GlyphRenderer"},{"id":"0fd2fa3f-ae52-4e7a-babb-eae827bc7983","type":"GlyphRenderer"},{"id":"35e7c162-2d31-4416-b91b-2d99b1c1ade6","type":"GlyphRenderer"}]],["versicolor",[{"id":"03c46aee-2751-492e-a402-c7883f6542cd","type":"GlyphRenderer"},{"id":"2c463e2f-c894-4a76-99c0-b7189414f1e0","type":"GlyphRenderer"},{"id":"ff36636c-844c-422a-a9d2-c1863d413672","type":"GlyphRenderer"}]],["virginica",[{"id":"bd38c4d8-b6f1-439d-aec6-be9a3693b498","type":"GlyphRenderer"},{"id":"e1f80693-6219-4f0a-9f40-22a2d5c6bbff","type":"GlyphRenderer"},{"id":"ced66a3f-8407-4f3d-acb3-cd54f9119e13","type":"GlyphRenderer"}]]],"location":"top_left","plot":{"id":"d938131d-541e-44a9-957e-ba047c87350e","subtype":"Chart","type":"Plot"}},"id":"8405171b-5388-4921-9658-c576f2220374","type":"Legend"},{"attributes":{"data_source":{"id":"2fbbe566-ba0e-4502-845d-ff83d7b94ec9","type":"ColumnDataSource"},"glyph":{"id":"c4d51379-e796-4380-bb9b-2166a462e9be","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0fd2fa3f-ae52-4e7a-babb-eae827bc7983","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_alpha","label","x","line_color","height","fill_alpha","color","y","width"],"data":{"chart_index":[{"species":"versicolor"}],"color":["#aa4444"],"fill_alpha":[0.8],"height":[0.19999999999999996],"label":[{"species":"versicolor"}],"line_alpha":[1.0],"line_color":["black"],"species":["versicolor"],"width":[0.8],"x":["versicolor"],"y":[1.4]}},"id":"ee922a62-71a8-49d1-9028-85b9d14b15a8","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"d938131d-541e-44a9-957e-ba047c87350e","subtype":"Chart","type":"Plot"}},"id":"c58c78a2-0d90-4619-8c2f-f71d4ed031ca","type":"CrosshairTool"},{"attributes":{"callback":null,"column_names":["line_alpha","label","x","line_color","height","fill_alpha","color","y","width"],"data":{"chart_index":[{"species":"virginica"}],"color":["#aa4444"],"fill_alpha":[0.8],"height":[0.19999999999999996],"label":[{"species":"virginica"}],"line_alpha":[1.0],"line_color":["black"],"species":["virginica"],"width":[0.8],"x":["virginica"],"y":[1.9]}},"id":"9ed857c3-1b34-4691-95f9-5299fc73d9a5","type":"ColumnDataSource"},{"attributes":{"callback":null,"factors":["setosa","versicolor","virginica"]},"id":"6ded2237-bfaa-4bae-97c8-8e28c5736755","type":"FactorRange"},{"attributes":{"callback":null,"column_names":["line_alpha","label","x","line_color","height","fill_alpha","color","y","width"],"data":{"chart_index":[{"species":"versicolor"}],"color":["#aa4444"],"fill_alpha":[0.8],"height":[0.10000000000000009],"label":[{"species":"versicolor"}],"line_alpha":[1.0],"line_color":["black"],"species":["versicolor"],"width":[0.8],"x":["versicolor"],"y":[1.25]}},"id":"db72428a-215f-46c8-9e0b-0e06f97380c8","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"chart_index":[{"species":"setosa"},{"species":"setosa"}],"species":["setosa","setosa"],"x_values":["setosa:0.5","setosa:0.5"],"y_values":[0.5,0.6]}},"id":"2fbbe566-ba0e-4502-845d-ff83d7b94ec9","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0a3a94a9-051c-44a3-bc46-14d75d4fd8a7","type":"Rect"},{"attributes":{},"id":"7dc1fe7c-3a42-42fa-b7ba-66e9a98c5806","type":"ToolEvents"},{"attributes":{},"id":"abf758a8-32fb-4e4e-b1c0-0cf7159afe98","type":"CategoricalTickFormatter"},{ ...

# %% [markdown]
# Instead of a single color, the box and whiskers groups can be colored by grouping one of the columns. This is done by passing a column name as the `color` parameter. Let's try that as an exercise.

# %%
# EXERCISE: color the boxes by "species" and add a legend to the top left

# %% [markdown]
# ---
#
# # Further reading

# %% [markdown]
# http://nbviewer.jupyter.org/github/bokeh/bokeh/tree/0.11.1/examples/charts/file/
#
# http://nbviewer.jupyter.org/github/bokeh/bokeh/tree/0.11.1/examples/howto/charts/
#
# http://nbviewer.jupyter.org/github/bokeh/bokeh-demos/blob/master/presentations/2016-03-pydata-strata/notebooks/Charts.ipynb
#
# http://nbviewer.jupyter.org/github/bokeh/bokeh-demos/blob/master/presentations/2016-03-pydata-strata/notebooks/Charts%20Demo.ipynb
