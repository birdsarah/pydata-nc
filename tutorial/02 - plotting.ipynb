# %% [markdown]
# <table style="float:left; border:none">
#    <tr style="border:none">
#        <td style="border:none">
#            <a href="http://bokeh.pydata.org/">
#            <img
#                src="assets/images/bokeh-transparent.png"
#                style="width:50px"
#            >
#            </a>
#        </td>
#        <td style="border:none">
#            <h1>Bokeh Tutorial</h1>
#        </td>
#    </tr>
# </table>
#
# <div style="float:right;"><h2>02. Basic Plotting Interface</h2></div>

# %% [markdown]
# This section of the tutorial covers the [`bokeh.plotting`](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html)
# interface. This interface is a "mid-level" interface, and the main idea can be described by the statement:
#
# **Starting from simple default figures (with sensible default tools, grids and axes), add markers and other shapes whose visual attributes are tied to directly data.**
#
# We will see that it is possible to customize and change all of the defaults, but having them means that it is possible to get up and running very quickly.

# %% [markdown]
# # Imports and Setup
#
# When using the [`bokeh.plotting`](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html) interface, there are a few common imports:
# * Use the [`figure`](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.figure) function to  create new plot objects to work with.
# * Call the functions [`output_file`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.output_file), [`output_notebook`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.output_notebook), and [`output_server`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.output_server) (possibly in combination) to tell Bokeh how to display or save output.
# * Execute [`show`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.show) and  [`save`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.save) to display or save plots and layouts.

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# %% [markdown]
# In this case, we are in the Jupyter notebook, so call `output_notebook()`. We only need to call this once, and all subsequent calls to `show()` will display inline in the notebook.

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ac128496-3ddc-4342-a2ff-e6a6dca875eb">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Some Basic Scatter Plots
#
# In this section you will see how to use Bokeh's various marker types to create simple scatter plots.

# %%
# create a new plot with default tools, using figure
p = figure(plot_width=400, plot_height=400)

# add a circle renderer with a size, color, and alpha
p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=15, line_color="navy", fill_color="orange", fill_alpha=0.5)

show(p) # show the results
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="6cdaeec6-6571-4f3f-92b2-ac130bcdf15e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#6cdaeec6-6571-4f3f-92b2-ac130bcdf15e").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6cdaeec6-6571-4f3f-92b2-ac130bcdf15e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6cdaeec6-6571-4f3f-92b2-ac130bcdf15e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"80981cbc-a4ab-4128-a0a1-61adb5a0efd5":{"roots":{"references":[{"attributes":{"callback":null},"id":"b2a06e2f-315e-49b7-944a-4455e49fc715","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"field":"x"},"y":{"field":"y"}},"id":"1a258c9a-c0a5-4a47-89b6-62b473c0848f","type":"Circle"},{"attributes":{},"id":"7e474505-0dfc-421e-8f69-49507cd2ea91","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"04ef0510-8cce-47f3-b493-f5bbfe49e325","type":"ColumnDataSource"},"glyph":{"id":"cb3ed180-67df-4285-a2c6-91b8af643755","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"1a258c9a-c0a5-4a47-89b6-62b473c0848f","type":"Circle"},"selection_glyph":null},"id":"275c7837-6f58-4c6b-8f7f-d46fe7e9ed51","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0ebf067e-f4a1-4668-8800-5cb83ebc1e0e","type":"PanTool"},{"id":"95937caa-be4b-4167-8bb8-95b4f33966fa","type":"WheelZoomTool"},{"id":"d317900d-555d-4ae3-b761-165ed25936ee","type":"BoxZoomTool"},{"id":"47a3ed55-4375-4cc5-ad28-c7db98bdcca4","type":"SaveTool"},{"id":"d0952221-f588-4409-8f65-62f130f004ee","type":"ResetTool"},{"id":"9f5da7b2-9389-4e57-a8f0-fef5d6deabfd","type":"HelpTool"}]},"id":"ccfc0b87-706c-4e28-91fb-5fdd7f8ce36b","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0bc76836-e7d0-4fa4-a774-6732833d6239","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"7e474505-0dfc-421e-8f69-49507cd2ea91","type":"BasicTickFormatter"},"plot":{"id":"bb006d34-a612-41df-94eb-21f9b9c7e45b","subtype":"Figure","type":"Plot"},"ticker":{"id":"134155ec-aaf2-4899-a2dc-e435c4564a6c","type":"BasicTicker"}},"id":"af9352bb-7c30-4f63-b88f-a6e169dd9b59","type":"LinearAxis"},{"attributes":{},"id":"a6b60e1c-e957-4b6e-93aa-40d1f6fb0eac","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"66beb511-2a63-40ec-9f23-8d2cdc1e2c70","type":"LinearAxis"}],"left":[{"id":"af9352bb-7c30-4f63-b88f-a6e169dd9b59","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"66beb511-2a63-40ec-9f23-8d2cdc1e2c70","type":"LinearAxis"},{"id":"ac6f79a7-0fff-490e-886e-323e1f40fc8d","type":"Grid"},{"id":"af9352bb-7c30-4f63-b88f-a6e169dd9b59","type":"LinearAxis"},{"id":"f97aba92-8f27-44bd-97c5-d0a5e227b6cd","type":"Grid"},{"id":"0bc76836-e7d0-4fa4-a774-6732833d6239","type":"BoxAnnotation"},{"id":"275c7837-6f58-4c6b-8f7f-d46fe7e9ed51","type":"GlyphRenderer"}],"title":{"id":"c46bcf32-9ee4-4a00-a9e5-7b1af72aeff5","type":"Title"},"tool_events":{"id":"69e1a0a2-d042-434c-95df-4334ea7be15e","type":"ToolEvents"},"toolbar":{"id":"ccfc0b87-706c-4e28-91fb-5fdd7f8ce36b","type":"Toolbar"},"x_range":{"id":"d02478e1-996a-449f-a494-089d91063dc7","type":"DataRange1d"},"y_range":{"id":"b2a06e2f-315e-49b7-944a-4455e49fc715","type":"DataRange1d"}},"id":"bb006d34-a612-41df-94eb-21f9b9c7e45b","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"bb006d34-a612-41df-94eb-21f9b9c7e45b","subtype":"Figure","type":"Plot"},"ticker":{"id":"2e58520c-bbf3-490b-b38f-44783776016c","type":"BasicTicker"}},"id":"ac6f79a7-0fff-490e-886e-323e1f40fc8d","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5],"y":[6,7,2,4,5]}},"id":"04ef0510-8cce-47f3-b493-f5bbfe49e325","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"d02478e1-996a-449f-a494-089d91063dc7","type":"DataRange1d"},{"attributes":{"plot":{"id":"bb006d34-a612-41df-94eb-21f9b9c7e45b","subtype":"Figure","type":"Plot"}},"id":"95937caa-be4b-4167-8bb8-95b4f33966fa","type":"WheelZoomTool"},{ ...

# %% [markdown]
# All Bokeh markers accept `size` (measured in screen space units) as a property. Circles also have `radius` (measured in "data" space units).

# %%
# EXERCISE: Try changing the example above to set a `radius` value instead of `size`

# %% [markdown]
# To scatter square markers instead of circles, you can use the `square` method on figures.

# %%
# create a new plot using figure
p = figure(plot_width=400, plot_height=400)

# add a square renderer with a size, color, alpha, and sizes
p.square([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=[10, 15, 20, 25, 30], color="firebrick", alpha=0.6)

show(p) # show the results
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="56566850-0cf9-4229-9c66-9c445851cd77"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#56566850-0cf9-4229-9c66-9c445851cd77").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("56566850-0cf9-4229-9c66-9c445851cd77");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '56566850-0cf9-4229-9c66-9c445851cd77' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"31aa760d-fd14-4e75-bf69-8d53f4f9c1f0":{"roots":{"references":[{"attributes":{"overlay":{"id":"04ef5414-fdd3-4317-bf7f-b29f4b4ddfc0","type":"BoxAnnotation"},"plot":{"id":"f6e40bd8-2ed2-4750-9e65-6a3262c1c082","subtype":"Figure","type":"Plot"}},"id":"fbbeccb0-8bce-4d32-9016-a9456abd2d7d","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"59b2b61d-e909-4102-b378-6a2e8c4e83a1","type":"ColumnDataSource"},"glyph":{"id":"e57cf529-b268-431d-92aa-3f112f817034","type":"Square"},"hover_glyph":null,"nonselection_glyph":{"id":"3ae09b28-4517-4791-9ff4-061c56f5fe23","type":"Square"},"selection_glyph":null},"id":"7e939ccc-13d2-4d65-a1ae-e10a50cc1237","type":"GlyphRenderer"},{"attributes":{"below":[{"id":
type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"li ...

# %% [markdown]
# Note that in the example above, we are also specifying different sizes for each individual marker. ***In general, all of a glyph's properties can be "vectorized" in this fashion. ***  Also note that we have passed ``color`` as a shorthand to set both the line and fill colors easily at the same time. This is a convenience specific to ``bokeh.plotting``.
#
# </table><p>There are many marker types available in Bokeh, you can see details and
# example plots for all of them in the reference guide by clicking on entries in the list below:</p>
# <table class="hlist" style="float:left"><tr><td><ul>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.asterisk" title="bokeh.plotting.Figure.asterisk"><code class="xref py py-func docutils literal"><span class="pre">asterisk()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.circle" title="bokeh.plotting.Figure.circle"><code class="xref py py-func docutils literal"><span class="pre">circle()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.circle_cross" title="bokeh.plotting.Figure.circle_cross"><code class="xref py py-func docutils literal"><span class="pre">circle_cross()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.circle_x" title="bokeh.plotting.Figure.circle_x"><code class="xref py py-func docutils literal"><span class="pre">circle_x()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.cross" title="bokeh.plotting.Figure.cross"><code class="xref py py-func docutils literal"><span class="pre">cross()</span></code></a></li>
# </ul>
# </td><td><ul>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.diamond" title="bokeh.plotting.Figure.diamond"><code class="xref py py-func docutils literal"><span class="pre">diamond()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.diamond_cross" title="bokeh.plotting.Figure.diamond_cross"><code class="xref py py-func docutils literal"><span class="pre">diamond_cross()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.inverted_triangle" title="bokeh.plotting.Figure.inverted_triangle"><code class="xref py py-func docutils literal"><span class="pre">inverted_triangle()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.square" title="bokeh.plotting.Figure.square"><code class="xref py py-func docutils literal"><span class="pre">square()</span></code></a></li>
# </ul>
# </td><td><ul>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.square_cross" title="bokeh.plotting.Figure.square_cross"><code class="xref py py-func docutils literal"><span class="pre">square_cross()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.square_x" title="bokeh.plotting.Figure.square_x"><code class="xref py py-func docutils literal"><span class="pre">square_x()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.triangle" title="bokeh.plotting.Figure.triangle"><code class="xref py py-func docutils literal"><span class="pre">triangle()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.x" title="bokeh.plotting.Figure.x"><code class="xref py py-func docutils literal"><span class="pre">x()</span></code></a></li>
# </ul>
# </td></tr></table>

# %%
# EXERCISE: Plot some different markers in this cell

# %% [markdown]
# # Basic Line Plots

# %%
# create a new plot (with a title) using figure
p = figure(plot_width=400, plot_height=400, title="My Line Plot")

# add a line renderer
p.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=2)

show(p) # show the results
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="df72ce3d-4b38-4132-9700-aa1aa4075c9e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#df72ce3d-4b38-4132-9700-aa1aa4075c9e").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("df72ce3d-4b38-4132-9700-aa1aa4075c9e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'df72ce3d-4b38-4132-9700-aa1aa4075c9e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9fb79a4d-6e2d-4dea-99c8-fc7670219d97":{"roots":{"references":[{"attributes":{"plot":{"id":"5dedcc73-eba7-4f00-a541-a17674f64756","subtype":"Figure","type":"Plot"}},"id":"236c049d-488c-4868-82b9-cd9507080b24","type":"PanTool"},{"attributes":{},"id":"e4f1cf61-9e1a-4bfb-af64-f0dbfb2ef135","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"5dedcc73-eba7-4f00-a541-a17674f64756","subtype":"Figure","type":"Plot"}},"id":"97ce775c-8eec-4911-9c29-df749f1ed73f","type":"ResetTool"},{"attributes":{"plot":{"id":"5dedcc73-eba7-4f00-a541-a17674f64756","subtype":"Figure","type":"Plot"}},"id":"7382e303-1acc-479b-b4f5-f6294d1236e9","type":"SaveTool"},{"attributes":{"callback":null},"id":"3913c809-9447-4708-96c1-3fb1ee082f7d","type":"DataRange1d"},{"attributes":{"below":[{"id":"9afb85d7-c154-4cf6-af35-748d918599d2","type":"LinearAxis"}],"left":[{"id":"12bf77a9-67e3-40f5-b73a-c8a46b572315","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":
type":"GlyphRenderer"},{"attributes":{"plot":{"id":"5dedcc73-eba7-4f00-a541-a17674f64756","subtype":"Figure","type":"Plot"}},"id":"0c973b3c-d7c9-44bb-aeb7-408c799176db","type":"HelpTool"},{"attributes":{"plot":null,"text":"My Line Plot"},"id":"94e6cdd3-75fd-4427-b8b5-5a6650cb2fd2","type":"Title"},{"attributes":{"ac ...

# %% [markdown]
# # Images

# %% [markdown]
# The example below shows how to use the `image_rgba` method to display raw RGBA data.
#
# **Note**: This example makes use of the NumPy library

# %%
from __future__ import division
import numpy as np

# set up some data
N = 20
img = np.empty((N,N), dtype=np.uint32)
view = img.view(dtype=np.uint8).reshape((N, N, 4))
for i in range(N):
    for j in range(N):
        view[i, j, 0] = int(i/N*255) # red
        view[i, j, 1] = 158          # green
        view[i, j, 2] = int(j/N*255) # blue
        view[i, j, 3] = 255          # alpha
        
# create a new plot (with a fixed range) using figure
p = figure(x_range=[0,10], y_range=[0,10])

# add an RGBA image renderer
p.image_rgba(image=[img], x=[0], y=[0], dw=[10], dh=[10])

show(p) # show the results
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="492014e6-e491-4e18-ae7f-df5cc2ff153c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#492014e6-e491-4e18-ae7f-df5cc2ff153c").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("492014e6-e491-4e18-ae7f-df5cc2ff153c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '492014e6-e491-4e18-ae7f-df5cc2ff153c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"71e30caf-07c6-4960-b198-5e22bcc58f89":{"roots":{"references":[{"attributes":{},"id":"a758bdc0-4427-4a51-9b65-a91f840229fa","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","image","dw","y","dh"],"data":{"dh":[10],"dw":[10],"image":[[[4278230528,4279016960,4279868928,4280720896,4281572864,4282359296,4283211264,4284063232,4284915200,4285701632,4286553600,4287405568,4288257536,4289043968,4289895936,4290747904,4291599872,4292386304,4293238272,4294090240],[4278230540,4279016972,4279868940,4280720908,4281572876,4282359308,4283211276,4284063244,4284915212,4285701644,4286553612,4287405580,4288257548,4289043980,4289895948,4290747916,4291599884,4292386316,4293238284,4294090252],[4278230553,4279016985,4279868953,4280720921,4281572889,4282359321,4283211289,4284063257,4284915225,4285701657,4286553625,4287405593,4288257561,4289043993,4289895961,4290747929,4291599897,4292386329,4293238297,4294090265],[4278230566,4279016998,4279868966,4280720934,4281572902,4282359334,4283211302,4284063270,4284915238,4285701670,4286553638,4287405606,4288257574,4289044006,4289895974,4290747942,4291599910,4292386342,4293238310,4294090278],[4278230579,4279017011,4279868979,4280720947,4281572915,4282359347,4283211315,4284063283,4284915251,4285701683,4286553651,4287405619,4288257587,4289044019,4289895987,4290747955,4291599923,4292386355,4293238323,4294090291],[4278230591,4279017023,4279868991,4280720959,4281572927,4282359359,4283211327,4284063295,4284915263,4285701695,4286553663,4287405631,4288257599,4289044031,4289895999,4290747967,4291599935,4292386367,4293238335,4294090303],[4278230604,4279017036,4279869004,4280720972,4281572940,4282359372,4283211340,4284063308,4284915276,4285701708,4286553676,4287405644,4288257612,4289044044,4289896012,4290747980,4291599948,4292386380,4293238348,4294090316],[4278230617,4279017049,4279869017,4280720985,4281572953,4282359385,4283211353,4284063321,4284915289,4285701721,4286553689,4287405657,4288257625,4289044057,4289896025,4290747993,4291599961,4292386393,4293238361,4294090329],[4278230630,4279017062,4279869030,4280720998,4281572966,4282359398,4283211366,4284063334,4284915302,4285701734,4286553702,4287405670,4288257638,4289044070,4289896038,4290748006,4291599974,4292386406,4293238374,4294090342],[4278230642,4279017074,4279869042,4280721010,4281572978,4282359410,4283211378,4284063346,4284915314,4285701746,4286553714,4287405682,4288257650,4289044082,4289896050,4290748018,4291599986,4292386418,4293238386,4294090354],[4278230655,4279017087,4279869055,4280721023,4281572991,4282359423,4283211391,4284063359,4284915327,4285701759,4286553727,4287405695,4288257663,4289044095,4289896063,4290748031,4291599999,4292386431,4293238399,4294090367],[4278230668,4279017100,4279869068,4280721036,4281573004,4282359436,4283211404,4284063372,4284915340,4285701772,4286553740,4287405708,4288257676,4289044108,4289896076,4290748044,4291600012,4292386444,4293238412,4294090380],[4278230681,4279017113,4279869081,4280721049,4281573017,4282359449,4283211417,4284063385,4284915353,4285701785,4286553753,4287405721,4288257689,4289044121,4289896089,4290748057,4291600025,4292386457,4293238425,4294090393],[4278230693,4279017125,4279869093,4280721061,4281573029,4282359461,4283211429,4284063397,4284915365,4285701797,4286553765,4287405733,4288257701,4289044133,4289896101,4290748069,4291600037,4292386469,4293238437,4294090405],[4278230706,4279017138,4279869106,4280721074,4281573042,4282359474,4283211442,4284063410,4284915378,4285701810,4286553778,4287405746,4288257714,4289044146,4289896114,4290748082,4291600050,4292386482,4293238450,4294090418],[4278230719,4279017151,4279869119,4280721087,4281573055,4282359487,4283211455,4284063423,4284915391,4285701823,4286553791,4287405759,4288257727,4289044159,4289896127,4290748095,4291600063,4292386495,4293238463,4294090431],[4278230732,4279017164,4279869132,4280721100,4281573068,4282359500,4283211468,4284063436,4284915404,4285701836,4286553804,4287405772,4288257740,4289044172 ...

# %% [markdown]
# # Other Kinds of Glyphs
#
# Bokeh supports many other kinds of glyphs. You can click on the User Guide links below to see how to create plots with these glyphs using the [`bokeh.plotting`](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html) interface.
#
# * [Rectangles and Ovals](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html#rectangles-and-ovals)
# * [Segments and Rays](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html#segments-and-rays)
# * [Wedges and Arcs](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html#wedges-and-arcs)
# * [Specialized Curves](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html#specialized-curves)

# %%
# EXERCISE: Plot some of the other glyph types, following the examples in the User Guide.

# %% [markdown]
# # Plots with Multiple Glyphs
#
# It is possible to combine more than one glyph on a single figure. You just need to call multiple glyph methods on one figure object:

# %%
# set up some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 8, 7, 3]

# create a new plot with figure
p = figure(plot_width=400, plot_height=400)

# add both a line and circles on the same plot
p.line(x, y, line_width=2)
p.circle(x, y, fill_color="white", size=8)

show(p) # show the results
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="60fa9882-5d61-4898-9e3d-2ace2ce4ab88"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#60fa9882-5d61-4898-9e3d-2ace2ce4ab88").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("60fa9882-5d61-4898-9e3d-2ace2ce4ab88");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '60fa9882-5d61-4898-9e3d-2ace2ce4ab88' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"153ba438-676b-40e3-b7c2-c7154f4572bb":{"roots":{"references":[{"attributes":{"formatter":{"id":"b2e97ed3-65e4-4acc-a5f6-8f998e7cbe24","type":"BasicTickFormatter"},"plot":{"id":"ae9e13f0-f786-4ee9-9d22-40d5069275bb","subtype":"Figure","type":"Plot"},"ticker":{"id":"74aa78ec-4af5-4c98-8176-0b15a4271c67","type":"BasicTicker"}},"id":"66f2fb21-0e39-4710-a642-4b4722d89944","type":"LinearAxis"},{"attributes":{"plot":null,"text":null},"id":"f37432bf-2bf2-4276-9a8a-483400339f2c","type":"Title"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"59c99c6c-9260-4c81-a81a-f70518aa4c0c","type":"Line"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"6bf8ca63-da3c-47c2-8e96-2c8fa38cc2e6","type":"PanTool"},{"id":"ac981453-7ec7-41c9-a866-8cb1a6e3cfcf","type":"WheelZoomTool"},{"id":"3b6ecda3-1801-4ca7-b498-60f12a83ce3b","type":"BoxZoomTool"},{"id":"c7e6edb9-4f59-47ae-9e3b-4403bb2fed25","type":"SaveTool"},{"id":"68317b4d-ae59-47d1-a2d9-bc55c6426c63","type":"ResetTool"},{"id":"91f8191b-fbee-485d-88d8-ccf927b6c92d","type":"HelpTool"}]},"id":"88b810fe-a06b-45bc-a406-c452d8596b4c","type":"Toolbar"},{"attributes":{"plot":{"id":"ae9e13f0-f786-4ee9-9d22-40d5069275bb","subtype":"Figure","type":"Plot"}},"id":"68317b4d-ae59-47d1-a2d9-bc55c6426c63","type":"ResetTool"},{"attributes":{"plot":{"id":"ae9e13f0-f786-4ee9-9d22-40d5069275bb","subtype":"Figure","type":"Plot"}},"id":"6bf8ca63-da3c-47c2-8e96-2c8fa38cc2e6","type":"PanTool"},{"attributes":{"data_source":{"id":"096a50fe-7e79-408c-b92c-6ac85d85edd5","type":"ColumnDataSource"},"glyph":{"id":"0ac8215c-f69d-4cc1-95f0-d862f302ec50","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"59c99c6c-9260-4c81-a81a-f70518aa4c0c","type":"Line"},"selection_glyph":null},"id":"91e468cf-07de-4f73-9b10-634039eec5cb","type":"GlyphRenderer"},{"attributes":{},"id":"1b0f07ee-25e9-472a-bb46-890c202f3761","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e5493953-02bd-4f63-844a-d01385ee68ca","type":"BoxAnnotation"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"0ac8215c-f69d-4cc1-95f0-d862f302ec50","type":"Line"},{"attributes":{"plot":{"id":"ae9e13f0-f786-4ee9-9d22-40d5069275bb","subtype":"Figure","type":"Plot"}},"id":"ac981453-7ec7-41c9-a866-8cb1a6e3cfcf","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"e5493953-02bd-4f63-844a-d01385ee68ca","type":"BoxAnnotation"},"plot":{"id":"ae9e13f0-f786-4ee9-9d22-40d5069275bb","subtype":"Figure","type":"Plot"}},"id":"3b6ecda3-1801-4ca7-b498-60f12a83ce3b","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"cc8c90fa-cf41-4e8a-bb2b-cad3224f9af4","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3,4,5],"y":[6,7,8,7,3]}},"id":"096a50fe-7e79-408c-b92c-6ac85d85edd5","type":"ColumnDataSource"},{"attributes":{},"id":"b2e97ed3-65e4-4acc-a5f6-8f998e7cbe24","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"ae9e13f0-f786-4ee9-9d22-40d5069275bb","subtype":"Figure","type":"Plot"}},"id":"c7e6edb9-4f59-47ae-9e3b-4403bb2fed25","type":"SaveTool"},{"attributes":{"callback":null},"id":"e296de30-74a3-4aed-a43a-ae20aecd453f","type":"DataRange1d"},{"attributes":{"plot":{"id":"ae9e13f0-f786-4ee9-9d22-40d5069275bb","subtype":"Figure","type":"Plot"}},"id":"91f8191b-fbee-485d-88d8-ccf927b6c92d","type":"HelpTool"},{"attributes":{"formatter":{"id":"d2f7613c-7966-4eae-a25e-39fa4cbd2607","type":"BasicTickFormatter"},"plot":{"id":"ae9e13f0-f786-4ee9-9d22-40d5069275bb","subtype":"Figure","type":"Plot"},"ticker":{"id":"db817 ...

# %%
# EXERCISE: create your own plot combining multiple glyphs together
