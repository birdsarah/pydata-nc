# %% [markdown]
# <table style="float:left; border:none">
#    <tr style="border:none">
#        <td style="border:none">
#            <a href="http://bokeh.pydata.org/">
#            <img
#                src="assets/images/bokeh-transparent.png"
#                style="width:50px"
#            >
#            </a>
#        </td>
#        <td style="border:none">
#            <h1>Bokeh Tutorial</h1>
#        </td>
#    </tr>
# </table>
#
# <div style="float:right;"><h2>07. Annotations</h2></div>

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4d708dbe-d411-4d8a-bf65-7389dd2b9791">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Overview
#
# Sometimes we want to add visual cues (boundary lines, shaded regions, labels and arrows, etc.) to our plots to call out some feature or other. Bokeh has several annotation types available for uses like this. Typically to add annotations we create the "low level" annotation object directly, and add it to our `Plot`, `Figure` or `Chart` using `add_layout`. Let's take a look at some specific examples.

# %% [markdown]
# ## Spans
#
# `Spans` are "infinite" vertical or horizonal lines. When creating them, you specify the `dimension` that should be spanned (i.e., `width` or `height`), any visual line properties for the appearance, and the location along the dimension where the line should be drawn. Let's look at an example that adds two horizontal spans to a simple plot:

# %%
import numpy as np
from bokeh.models.annotations import Span

x = np.linspace(0, 20, 200)
y = np.sin(x)

p = figure(y_range=(-2, 2))
p.line(x, y)

upper = Span(location=1, dimension='width', line_color='olive', line_width=4)
p.add_layout(upper)

lower = Span(location=-1, dimension='width', line_color='firebrick', line_width=4)
p.add_layout(lower)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="e94ba551-f7a2-40f1-8c6d-52a2c32ed0f5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#e94ba551-f7a2-40f1-8c6d-52a2c32ed0f5").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e94ba551-f7a2-40f1-8c6d-52a2c32ed0f5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e94ba551-f7a2-40f1-8c6d-52a2c32ed0f5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"33f1ec43-5ed5-4479-b5bc-64c94b74e9bd":{"roots":{"references":[{"attributes":{},"id":"61ad3bdd-a8a7-4362-b2f9-0760dece7b29","type":"ToolEvents"},{"attributes":{"formatter":{"id":"644675ca-58fa-43d8-b8da-5f317bd15d30","type":"BasicTickFormatter"},"plot":{"id":"3ac7a761-4221-4f2f-860a-d788d7087e10","subtype":"Figure","type":"Plot"},"ticker":{"id":"6c9a5fd3-28c6-44b1-b942-9fa6090c2f94","type":"BasicTicker"}},"id":"d1187d29-77a1-448d-8539-e47b5e9362e0","type":"LinearAxis"},{"attributes":{"line_color":{"value":"firebrick"},"line_width":{"value":4},"location":-1,"plot":{"id":"3ac7a761-4221-4f2f-860a-d788d7087e10","subtype":"Figure","type":"Plot"}},"id":"f72dc672-c979-4011-9425-907637fdea49","type":"Span"},{"attributes":{"line_color":{"value":"olive"},"line_width":{"value":4},"location":1,"plot":{"id":"3ac7a761-4221-4f2f-860a-d788d7087e10","subtype":"Figure","type":"Plot"}},"id":"82e5799f-27aa-4bff-ad1f-6c774219a4cd","type":"Span"},{"attributes":{"plot":{"id":"3ac7a761-4221-4f2f-860a-d788d7087e10","subtype":"Figure","type":"Plot"}},"id":"50160ae1-3365-4bf1-a6a5-3492050f7fc9","type":"WheelZoomTool"},{"attributes":{},"id":"6c9a5fd3-28c6-44b1-b942-9fa6090c2f94","type":"BasicTicker"},{"attributes":{"plot":null,"text":null},"id":"cf30b858-b4f4-4305-bec1-4ddf264bb957","type":"Title"},{"attributes":{"plot":{"id":"3ac7a761-4221-4f2f-860a-d788d7087e10","subtype":"Figure","type":"Plot"}},"id":"8409f0e9-ef55-493d-aafc-6de7a780acf6","type":"HelpTool"},{"attributes":{"plot":{"id":"3ac7a761-4221-4f2f-860a-d788d7087e10","subtype":"Figure","type":"Plot"},"ticker":{"id":"6c9a5fd3-28c6-44b1-b942-9fa6090c2f94","type":"BasicTicker"}},"id":"3a1666ac-8b16-42e3-887a-f0750415f04d","type":"Grid"},{"attributes":{},"id":"0701c862-81ae-4be2-a18f-68b4b385dfb4","type":"BasicTicker"},{"attributes":{"data_source":{"id":"6f62a718-2eaa-4335-b541-4011e96142e2","type":"ColumnDataSource"},"glyph":{"id":"340505d0-2e41-4968-bcdb-62b75f4c7cc1","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"4f92218a-bf5e-4ffc-8d43-224f34b96e40","type":"Line"},"selection_glyph":null},"id":"648bf8e4-b32b-44ad-92de-f7796e3cb826","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"3ac7a761-4221-4f2f-860a-d788d7087e10","subtype":"Figure","type":"Plot"}},"id":"b14d815d-a89b-4786-a0a6-091d073a14f8","type":"PanTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b14d815d-a89b-4786-a0a6-091d073a14f8","type":"PanTool"},{"id":"50160ae1-3365-4bf1-a6a5-3492050f7fc9","type":"WheelZoomTool"},{"id":"f66660a4-7f42-41c3-a72e-36ef461c0695","type":"BoxZoomTool"},{"id":"b832ebdc-b491-44c1-9854-4a831d4b4ba8","type":"SaveTool"},{"id":"27401da7-f763-428b-9c6c-09a67cfd8c13","type":"ResetTool"},{"id":"8409f0e9-ef55-493d-aafc-6de7a780acf6","type":"HelpTool"}]},"id":"c36e0d33-2217-4bc3-b220-541af2ca60a6","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d8821187-70e5-4fc3-917f-c71ccb532cfe","type":"BoxAnnotation"},{"attributes":{},"id":"644675ca-58fa-43d8-b8da-5f317bd15d30","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"d8821187-70e5-4fc3-917f-c71ccb532cfe","type":"BoxAnnotation"},"plot":{"id":"3ac7a761-4221-4f2f-860a-d788d7087e10","subtype":"Figure","type":"Plot"}},"id":"f66660a4-7f42-41c3-a72e-36ef461c0695","type":"BoxZoomTool"},{"attributes":{},"id":"927ac361-fc72-4ecc-be73-f3b9f01fc59a","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"340505d0-2e41-4968-bcdb-62b75f4c7cc1","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4f92218a-bf5e-4ffc-8d43-224f34b96e40","type":"Lin ...

# %% [markdown]
# ## Box Annotations
#
# Sometimes you might want to call out some region of the plot by drawing a shaded box. This can be done with the `BoxAnnotation`, which is configured with the coordinate properties:
# * `top`
# * `left`
# * `bottom`
# * `right`
#
# as well as any visual line or fill properties to control the appearance.
#
# "Infinite" boxes can be made by leaving any of the coordinates unspecified. E.g., if `top` is not given, the box will always extend to the top of the plot area, regardless of any panning or zooming that happens.
#
# Let's take a look at an example that adds a few shaded boxes to a plot:

# %%
import numpy as np
from bokeh.models.annotations import BoxAnnotation

x = np.linspace(0, 20, 200)
y = np.sin(x)

p = figure(y_range=(-2, 2))
p.line(x, y)

# region that always fills the top of the plot
upper = BoxAnnotation(bottom=1, fill_alpha=0.1, fill_color='olive')
p.add_layout(upper)

# region that always fills the bottom of the plot
lower = BoxAnnotation(top=-1, fill_alpha=0.1, fill_color='firebrick')
p.add_layout(lower)

# a finite region
center = BoxAnnotation(top=0.6, bottom=-0.3, left=7, right=12, fill_alpha=0.1, fill_color='navy')
p.add_layout(center)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id
,14.472361809045227,14.57286432160804,14.673366834170855,14.773869346733669,14.874371859296483,14.974874371859297,15.075376884422111,15.175879396984925,15.27638190954774,15.376884422110553,15.477386934673367,15.577889447236181,15.678391959798995,15.77889447236181,15.879396984924623,15.979899497487438,16.080402010050253,16.180904522613066,16.28140703517588,16.381909547738694,16.48241206030151,16.582914572864322,16.683417085427138,16.78391959798995,16.884422110552766,16.984924623115578,17.085427135678394,17.185929648241206,17.286432160804022,17.386934673366834,17.48743718592965,17.587939698492463,17.68844221105528,17.78894472361809,17.889447236180906,17.98994974874372,18.090452261306535,18.190954773869347,18.291457286432163,18.391959798994975,18.49246231155779,18.592964824120603,18.69346733668342,18.79396984924623,18.894472361809047,18.99497487437186,19.095477386934675,19.195979899497488,19.296482412060303,19.396984924623116,19.49748743718593,19.597989949748744,19.69849246231156,19.798994974874372,19.89949748 ...

# %% [markdown]
# ## Label
#
# The `Label` annoation allows you to easily attach single text labels to plots. The position and text to display are configured as `x`, `y`, and `text`:
#
# ```python
# Label(x=10, y=5, text="Some Label")
# ```
#
# By default the units are in "data space" but `x_units` and `y_units` maybe set to `"screen"` to position the label relative to the canvas. Labels can also accept `x_offset` and `y_offset` to offset the final position from `x` and `y` by a given screen space distance.
#
# `Label` objects also have standard text, line (`border_line`) and fill (`background_fill`) properties. The line and fill properties apply to a bounding box around the text:
#
# ```python
# Label(x=10, y=5, text="Some Label", text_font_size="12pt",
#       border_line_color="red", background_fill_color="blue")
# ```

# %%
from bokeh.models.annotations import Label
from bokeh.plotting import figure

p = figure(x_range=(0,10), y_range=(0,10))
p.circle([2, 5, 8], [4, 7, 6], color="olive", size=10)

label = Label(x=5, y=7, x_offset=12, text="Second Point", text_baseline="middle")
p.add_layout(label)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="a4b1fb1c-6ec6-4aca-a4b7-8503a6590fe6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#a4b1fb1c-6ec6-4aca-a4b7-8503a6590fe6").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a4b1fb1c-6ec6-4aca-a4b7-8503a6590fe6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a4b1fb1c-6ec6-4aca-a4b7-8503a6590fe6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8329ce5b-de16-4ecd-bcb1-b831c03e9de6":{"roots":{"references":[{"attributes":{"plot":{"id":"68fbafd4-ef15-40e2-ad42-f0d75303b451","subtype":"Figure","type":"Plot"}},"id":"e96db7ab-c616-4cbf-b463-cc29efb1fed5","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"9e4b462e-ce42-4583-be1d-e646405b9f6f","type":"Circle"},{"attributes":{"plot":{"id":"68fbafd4-ef15-40e2-ad42-f0d75303b451","subtype":"Figure","type":"Plot"}},"id":"9a0b684b-47d2-4d9b-be3b-ff1537868da0","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[2,5,8],"y":[4,7,6]}},"id":"861c2bf0-2b80-442b-8169-5251701bddb9","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d68fb263-72eb-4dd6-81fb-9a27606a797a","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"68fbafd4-ef15-40e2-ad42-f0d75303b451","subtype":"Figure","type":"Plot"}},"id":"ff79981e-fada-4993-a44d-b074718ca677","type":"SaveTool"},{"attributes":{"overlay":{"id":"d68fb263-72eb-4dd6-81fb-9a27606a797a","type":"BoxAnnotation"},"plot":{"id":"68fbafd4-ef15-40e2-ad42-f0d75303b451","subtype":"Figure","type":"Plot"}},"id":"8b4fb510-519c-49c9-9d71-9ad2434813e3","type":"BoxZoomTool"},{"attributes":{"callback":null,"end":10},"id":"7a44dfa6-7c3f-471a-94b9-890de4e3b838","type":"Range1d"},{"attributes":{},"id":"4e09c9dd-853c-401e-8192-7f87e2391619","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"68fbafd4-ef15-40e2-ad42-f0d75303b451","subtype":"Figure","type":"Plot"},"text":"Second Point","text_baseline":"middle","x":5,"x_offset":12,"y":7},"id":"fed9fb00-4a5e-41e7-b83f-38a70a9963b8","type":"Label"},{"attributes":{},"id":"0dce7aa0-cbf8-4744-9f03-c6e3a46db9fa","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"308ddd10-9a42-4692-ae7f-2dbeeb23dd5a","type":"PanTool"},{"id":"e96db7ab-c616-4cbf-b463-cc29efb1fed5","type":"WheelZoomTool"},{"id":"8b4fb510-519c-49c9-9d71-9ad2434813e3","type":"BoxZoomTool"},{"id":"ff79981e-fada-4993-a44d-b074718ca677","type":"SaveTool"},{"id":"9a0b684b-47d2-4d9b-be3b-ff1537868da0","type":"ResetTool"},{"id":"569797c4-b621-4fa9-8366-905594cbd902","type":"HelpTool"}]},"id":"0eeb28be-29ac-403d-8513-ffb8e549470c","type":"Toolbar"},{"attributes":{"callback":null,"end":10},"id":"bf03d49b-1451-4abe-b41d-c391f8f82cd6","type":"Range1d"},{"attributes":{"below":[{"id":"918d539c-71cf-4d8b-8e9f-6a4e67a9d703","type":"LinearAxis"}],"left":[{"id":"507bf355-f175-4e0c-9ebb-485dfd65efef","type":"LinearAxis"}],"renderers":[{"id":"918d539c-71cf-4d8b-8e9f-6a4e67a9d703","type":"LinearAxis"},{"id":"4f9614a0-c757-40ae-80a0-407b657c15b1","type":"Grid"},{"id":"507bf355-f175-4e0c-9ebb-485dfd65efef","type":"LinearAxis"},{"id":"9a3da837-daa5-452c-aba1-afc8188a542a","type":"Grid"},{"id":"d68fb263-72eb-4dd6-81fb-9a27606a797a","type":"BoxAnnotation"},{"id":"62de683e-b308-40e3-8047-c3e0d01d7661","type":"GlyphRenderer"},{"id":"fed9fb00-4a5e-41e7-b83f-38a70a9963b8","type":"Label"}],"title":{"id":"2959fdb3-9768-4526-9425-48fd4f1b8d2c","type":"Title"},"tool_events":{"id":"1ac96e0f-93fd-4e7d-b314-80eb37305aac","type":"ToolEvents"},"toolbar":{"id":"0eeb28be-29ac-403d-8513-ffb8e549470c","type":"Toolbar"},"x_range":{"id":"bf03d49b-1451-4abe-b41d-c391f8f82cd6","type":"Range1d"},"y_range":{"id":"7a44dfa6-7c3f-471a-94b9-890de4e3b838","type":"Range1d"}},"id":"68fbafd4-ef15-40e2-ad42-f0d75303b451","subtype":"Figure","type":"Plot"},{"attributes":{"fill_color":{"value":"olive"},"line_color":{"value":"olive"},"size":{"units":"screen","val ...

# %%
# EXERCISE: experiment with Label

# %% [markdown]
# ## LabelSet
#
# The `LabelSet` annotation allows you to create many labels at once, for instance if you want to label an entire set of scatter markers. They are similar to `Label`, but they can also
# accept a `ColumnDataSource` as the `source` property, and then `x` and `y` may refer to columns in the data source, e.g. `x="col2"` (but may also still be fixed values, e.g. `x=10`).

# %%
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, LabelSet


source = ColumnDataSource(data=dict(
    temp=[166, 171, 172, 168, 174, 162],
    pressure=[165, 189, 220, 141, 260, 174],
    names=['A', 'B', 'C', 'D', 'E', 'F']))

p = figure(x_range=(160, 175))
p.scatter(x='temp', y='pressure', size=8, source=source)
p.xaxis.axis_label = 'Temperature (C)'
p.yaxis.axis_label = 'Pressure (lbs)'

labels = LabelSet(x='temp', y='pressure', text='names', level='glyph',
                  x_offset=5, y_offset=5, source=source, render_mode='canvas')


p.add_layout(labels)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="65b67788-ceb5-4ae7-ae84-e36c9dacd92a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#65b67788-ceb5-4ae7-ae84-e36c9dacd92a").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("65b67788-ceb5-4ae7-ae84-e36c9dacd92a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '65b67788-ceb5-4ae7-ae84-e36c9dacd92a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"24cfe188-6270-4a61-bf1e-5829ad7c6681":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5d1145d6-d31a-42d9-bc80-444932275af2","type":"PanTool"},{"id":"af23a250-a95e-44d7-a3c0-549d67b7c73f","type":"WheelZoomTool"},{"id":"6f54cbf1-72b5-46c0-8a71-9d8c92311a63","type":"BoxZoomTool"},{"id":"9c85c07d-7f88-427d-83a7-08408a650b5a","type":"SaveTool"},{"id":"bd2dc6b3-6a20-4a0c-95cc-cb955a1dd25a","type":"ResetTool"},{"id":"dc3fe41b-7140-495f-b379-1f0bbe98e02e","type":"HelpTool"}]},"id":"a7395fe6-ff3b-4813-8566-574491ee5c85","type":"Toolbar"},{"attributes":{"axis_label":"Pressure (lbs)","formatter":{"id":"fdb2654c-3f2d-4f54-937b-7449858ae378","type":"BasicTickFormatter"},"plot":{"id":"a648e0ab-c4a9-4a7d-8564-e2ccc26b9854","subtype":"Figure","type":"Plot"},"ticker":{"id":"57440d1d-b683-426d-85ca-1d84366de194","type":"BasicTicker"}},"id":"eaae2782-4f8d-487c-b932-0a954bb6a6b6","type":"LinearAxis"},{"attributes":{"plot":null,"text":null},"id":"265a0e77-f9b7-44df-81e3-b4510ccb1b27","type":"Title"},{"attributes":{},"id":"dd5c6c2b-a7a9-4f7e-80d4-eaf04b240e90","type":"ToolEvents"},{"attributes":{"level":"glyph","plot":{"id":"a648e0ab-c4a9-4a7d-8564-e2ccc26b9854","subtype":"Figure","type":"Plot"},"source":{"id":"aedf4bc1-0e47-4a25-b54b-371d4e2e245f","type":"ColumnDataSource"},"text":{"field":"names"},"x":{"field":"temp"},"x_offset":{"value":5},"y":{"field":"pressure"},"y_offset":{"value":5}},"id":"e5e89731-bbcb-4645-879b-d5aeebe9eded","type":"LabelSet"},{"attributes":{"dimension":1,"plot":{"id":"a648e0ab-c4a9-4a7d-8564-e2ccc26b9854","subtype":"Figure","type":"Plot"},"ticker":{"id":"57440d1d-b683-426d-85ca-1d84366de194","type":"BasicTicker"}},"id":"c1d69bd9-802e-4cec-b281-01764b8dda85","type":"Grid"},{"attributes":{"plot":{"id":"a648e0ab-c4a9-4a7d-8564-e2ccc26b9854","subtype":"Figure","type":"Plot"}},"id":"bd2dc6b3-6a20-4a0c-95cc-cb955a1dd25a","type":"ResetTool"},{"attributes":{"axis_label":"Temperature (C)","formatter":{"id":"c0425064-a273-449b-8313-45e2cc864ce0","type":"BasicTickFormatter"},"plot":{"id":"a648e0ab-c4a9-4a7d-8564-e2ccc26b9854","subtype":"Figure","type":"Plot"},"ticker":{"id":"b5129a26-236d-4831-b091-9d26c5863e4b","type":"BasicTicker"}},"id":"b877a02f-ae13-4085-b2dc-57754e56f989","type":"LinearAxis"},{"attributes":{"plot":{"id":"a648e0ab-c4a9-4a7d-8564-e2ccc26b9854","subtype":"Figure","type":"Plot"}},"id":"5d1145d6-d31a-42d9-bc80-444932275af2","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b4d7483f-a186-4f20-acc8-43b42dd5ae25","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"b877a02f-ae13-4085-b2dc-57754e56f989","type":"LinearAxis"}],"left":[{"id":"eaae2782-4f8d-487c-b932-0a954bb6a6b6","type":"LinearAxis"}],"renderers":[{"id":"b877a02f-ae13-4085-b2dc-57754e56f989","type":"LinearAxis"},{"id":"123ff8d5-ee5c-4670-88be-11503d3537ba","type":"Grid"},{"id":"eaae2782-4f8d-487c-b932-0a954bb6a6b6","type":"LinearAxis"},{"id":"c1d69bd9-802e-4cec-b281-01764b8dda85","type":"Grid"},{"id":"b4d7483f-a186-4f20-acc8-43b42dd5ae25","type":"BoxAnnotation"},{"id":"3f82f233-67da-4abb-a07b-7383c910424d","type":"GlyphRenderer"},{"id":"e5e89731-bbcb-4645-879b-d5aeebe9eded","type":"LabelSet"}],"title":{"id":"265a0e77-f9b7-44df-81e3-b4510ccb1b27","type":"Title"},"tool_events":{"id":"dd5c6c2b-a7a9-4f7e-80d4-eaf04b240e90","type":"ToolEvents"},"toolbar":{"id":"a7395fe6-ff3b-4813-8566-574491ee5c85","type":"Toolbar"},"x_range":{"id":"28f19b3b-1ca5-4038-ad60-228aa88d15cc","type":"Range1d"},"y_range":{"id":"90ac14b2-43ce-436e-8564-65868e18ac29","type":"DataRange1d"}},"id":"a648e0ab-c4a9-4a7d-8564-e2ccc26b9854","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null, ...

# %%
# EXERCISE: experiment with LabelSet

# %% [markdown]
# ## Arrows
#
# The `Arrow` annotation allows you to "point" at different things on your plot, and can be especially useful in conjuction with labels.
#
# For example, to create an arrow that points from `(0,0)` to `(1,1)`:
#
# ```python
# p.add_layout(Arrow(x_start=0, y_start=0, x_end=1, y_end=0))
# ```
#
# This arrow will have the default [`OpenHead`](http://bokeh.pydata.org/en/latest/docs/reference/models/arrow_heads.html#bokeh.models.arrow_heads.OpenHead) arrow head at the end of the arrow. Other kinds of arrow heads include [`NormalHead`](http://bokeh.pydata.org/en/latest/docs/reference/models/arrow_heads.html#bokeh.models.arrow_heads.NormalHead) and [`VeeHead`](http://bokeh.pydata.org/en/latest/docs/reference/models/arrow_heads.html#bokeh.models.arrow_heads.VeeHead). The arrow head type can be controlled by setting the `start` and `end` properties of `Arrow` objects:
#
# ```python
# p.add_layout(Arrow(start=OpenHead(), end=VeeHead(),
#              x_start=0, y_start=0, x_end=1, y_end=0))
# ```
#
# This will create a double-ended arrow with an "open" head at the start, and a "vee" head at the end. Arrowheads have the standard set of line and fill properties to control their appearance. As an example
#
# ```python
# OpenHead(line_color="firebrick", line_width=4)
# ```
#
# The code and plot below shows several of these configurations together.

# %%
from bokeh.models.annotations import Arrow
from bokeh.models.arrow_heads import OpenHead, NormalHead, VeeHead

p = figure(plot_width=600, plot_height=600)

p.circle(x=[0, 1, 0.5], y=[0, 0, 0.7], radius=0.1,
         color=["navy", "yellow", "red"], fill_alpha=0.1)

p.add_layout(Arrow(end=OpenHead(line_color="firebrick", line_width=4),
                   x_start=0, y_start=0, x_end=1, y_end=0))

p.add_layout(Arrow(end=NormalHead(fill_color="orange"),
                   x_start=1, y_start=0, x_end=0.5, y_end=0.7))

p.add_layout(Arrow(end=VeeHead(size=35), line_color="red",
                   x_start=0.5, y_start=0.7, x_end=0, y_end=0))

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="facfe91e-a2b0-456f-ae1b-a9d96d119c69"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#facfe91e-a2b0-456f-ae1b-a9d96d119c69").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("facfe91e-a2b0-456f-ae1b-a9d96d119c69");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'facfe91e-a2b0-456f-ae1b-a9d96d119c69' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"55e0225e-e7d3-4b1b-954f-887ddd5ddebb":{"roots":{"references":[{"attributes":{},"id":"6eaa7f0a-31a7-45e5-8304-32b23f538a17","type":"BasicTicker"},{"attributes":{"data_source":{"id":"019592cd-4807-47ee-b3d8-e04f8b17fa48","type":"ColumnDataSource"},"glyph":{"id":"b06c8898-a2cf-446e-b021-0a0234dbff65","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"d4a9ae96-0080-4d81-9c05-5590a914dd5d","type":"Circle"},"selection_glyph":null},"id":"3be10889-f149-40cd-9f4e-d7d0c2375b27","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"65632127-093c-475a-9a79-c591f19b6e89","type":"DataRange1d"},{"attributes":{"plot":{"id":"46612fda-c273-470c-a7e9-4d06986af69a","subtype":"Figure","type":"Plot"}},"id":"cc27858b-9fa6-4507-9b57-a6f78a2e90a4","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"field":"fill_color"},"line_color":{"field":"line_color"},"radius":{"units":"data","value":0.1},"x":{"field":"x"},"y":{"field":"y"}},"id":"b06c8898-a2cf-446e-b021-0a0234dbff65","type":"Circle"},{"attributes":{"plot":{"id":"46612fda-c273-470c-a7e9-4d06986af69a","subtype":"Figure","type":"Plot"}},"id":"a90cd46e-9124-4e9d-bfac-0a09bf03758b","type":"PanTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"